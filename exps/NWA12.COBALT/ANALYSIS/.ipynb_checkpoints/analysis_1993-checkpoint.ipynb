# %%
import numpy as np
import matplotlib as mpl
import matplotlib.path as mpath
from matplotlib import rc
import matplotlib.pyplot as plt
import netCDF4 as nc 
import pandas as pd 
import xarray as xr
import seaborn as sns
import scipy
import dask
import h5py
import matplotlib.animation as animation
from IPython.display import HTML
from PIL import Image
from cycler import cycler
import cmocean
from matplotlib.colors import TwoSlopeNorm

np.random.seed(4321)
plt.rcParams.update({'font.size': 12})
print('all done')
# %matplotlib inline
nanmasked = plt.get_cmap('RdBu').copy()
nanmasked.set_bad('black')
nanmasked2 = mpl.colors.LinearSegmentedColormap.from_list("", ["white","red"])
nanmasked2.set_bad('black')
# Out:
# all done

# %%
# data_path = '/scratch/gpfs/CDEUTSCH/wchu/CEFI-regional-MOM6/exps/NWA12.COBALT/OUTPUT/combined/19930101.ocean_daily_1993'_01.nc'
# dsnow = xr.open_dataset(data_path,chunks='auto')

# combining all the data between jan and nov
# data_path = '/scratch/gpfs/CDEUTSCH/wchu/CEFI-regional-MOM6/exps/NWA12.COBALT/OUTPUT/combined/19930101.ocean_daily_budgets_1993_'
# ds = xr.concat([xr.open_dataset(data_path+'{:02}'.format(i)+'.nc',chunks='auto') for i in range(1, 12)],dim='time')
# ds = ds.rename({'xh_sub01': 'xh','yh_sub01': 'yh'})

ds.variables
# Out:
# Frozen({'volcello': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          m3
#     long_name:      Ocean grid-cell volume
#     cell_methods:   area:sum z_l:sum yh:sum xh:sum time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  ocean_volume, 'Th_tendency': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          W m-2
#     long_name:      Net time tendency for heat
#     cell_methods:   area:mean z_l:sum yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'T_advection_xy': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          W m-2
#     long_name:      Horizontal convergence of residual mean advective fluxes ...
#     cell_methods:   area:mean z_l:sum yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'T_tendency_vert_remap': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          W m-2
#     long_name:      Vertical remapping tracer content tendency for Heat
#     cell_methods:   area:mean z_l:sum yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'boundary_forcing_heat_tendency': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          W m-2
#     long_name:      Boundary forcing heat tendency
#     cell_methods:   area:mean z_l:sum yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'diabatic_heat_tendency': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          W m-2
#     long_name:      Diabatic diffusion heat tendency
#     cell_methods:   area:mean z_l:sum yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'frazil_heat_tendency': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          W m-2
#     long_name:      Heat tendency due to frazil formation
#     cell_methods:   area:mean z_l:sum yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'o2': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          mol/kg
#     long_name:      Oxygen
#     cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'o2min': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          mol/kg
#     long_name:      Oxygen
#     cell_methods:   area:mean z_l:mean yh:mean xh:mean time: min
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'o2max': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          mol/kg
#     long_name:      Oxygen
#     cell_methods:   area:mean z_l:mean yh:mean xh:mean time: max
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'o2h_tendency': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          mol/kg m s-1
#     long_name:      Net time tendency for oxygen
#     cell_methods:   area:mean z_l:sum yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'o2_advection_xy': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          mol/kg m s-1
#     long_name:      Horizontal convergence of residual mean advective fluxes ...
#     cell_methods:   area:mean z_l:sum yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'o2h_tendency_vert_remap': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          mol/kg m s-1
#     long_name:      Vertical remapping tracer content tendency for Oxygen
#     cell_methods:   area:mean z_l:sum yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'o2_vdiffuse_impl': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          mol kg-1 m s-1
#     long_name:      Implicit vertical diffusion of o2
#     cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'jo2': <xarray.Variable (time: 334, z_l: 52, yh: 343, xh: 601)> Size: 14GB
# dask.array<concatenate, shape=(334, 52, 343, 601), dtype=float32, chunksize=(3, 52, 343, 601), chunktype=numpy.ndarray>
# Attributes:
#     units:          mol m-2 s-1
#     long_name:      O2 source concentration layer integral
#     cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT, 'average_T1': <xarray.Variable (time: 334)> Size: 3kB
# dask.array<concatenate, shape=(334,), dtype=datetime64[ns], chunksize=(31,), chunktype=numpy.ndarray>
# Attributes:
#     long_name:  Start time for average period, 'average_T2': <xarray.Variable (time: 334)> Size: 3kB
# dask.array<concatenate, shape=(334,), dtype=datetime64[ns], chunksize=(31,), chunktype=numpy.ndarray>
# Attributes:
#     long_name:  End time for average period, 'average_DT': <xarray.Variable (time: 334)> Size: 3kB
# dask.array<concatenate, shape=(334,), dtype=timedelta64[ns], chunksize=(31,), chunktype=numpy.ndarray>
# Attributes:
#     long_name:  Length of average period, 'time_bnds': <xarray.Variable (time: 334, nv: 2)> Size: 5kB
# dask.array<concatenate, shape=(334, 2), dtype=datetime64[ns], chunksize=(31, 2), chunktype=numpy.ndarray>
# Attributes:
#     long_name:  time axis boundaries, 'xh': <xarray.IndexVariable 'xh' (xh: 601)> Size: 5kB
# array([-98.      , -97.920013, -97.839996, ..., -50.160004, -50.079987,
#        -50.      ])
# Attributes:
#     units:      degrees_east
#     long_name:  h point nominal longitude
#     axis:       X, 'yh': <xarray.IndexVariable 'yh' (yh: 343)> Size: 3kB
# array([ 5.272542,  5.352199,  5.431845, ..., 30.868299, 30.936943, 31.005537])
# Attributes:
#     units:      degrees_north
#     long_name:  h point nominal latitude
#     axis:       Y, 'z_l': <xarray.IndexVariable 'z_l' (z_l: 52)> Size: 416B
# array([2.500e+00, 7.500e+00, 1.250e+01, 1.750e+01, 2.250e+01, 2.750e+01,
#        3.250e+01, 3.750e+01, 4.250e+01, 4.750e+01, 5.500e+01, 6.500e+01,
#        7.500e+01, 8.500e+01, 9.500e+01, 1.050e+02, 1.150e+02, 1.250e+02,
#        1.350e+02, 1.450e+02, 1.625e+02, 1.875e+02, 2.125e+02, 2.375e+02,
#        2.625e+02, 2.875e+02, 3.250e+02, 3.750e+02, 4.250e+02, 4.750e+02,
#        5.500e+02, 6.500e+02, 7.500e+02, 8.500e+02, 9.500e+02, 1.050e+03,
#        1.150e+03, 1.250e+03, 1.350e+03, 1.450e+03, 1.625e+03, 1.875e+03,
#        2.125e+03, 2.375e+03, 2.750e+03, 3.250e+03, 3.750e+03, 4.250e+03,
#        4.750e+03, 5.250e+03, 5.750e+03, 6.250e+03])
# Attributes:
#     units:      meters
#     long_name:  Depth at cell center
#     axis:       Z
#     positive:   down
#     edges:      z_i, 'z_i': <xarray.IndexVariable 'z_i' (z_i: 53)> Size: 424B
# array([0.00e+00, 5.00e+00, 1.00e+01, 1.50e+01, 2.00e+01, 2.50e+01, 3.00e+01,
#        3.50e+01, 4.00e+01, 4.50e+01, 5.00e+01, 6.00e+01, 7.00e+01, 8.00e+01,
#        9.00e+01, 1.00e+02, 1.10e+02, 1.20e+02, 1.30e+02, 1.40e+02, 1.50e+02,
#        1.75e+02, 2.00e+02, 2.25e+02, 2.50e+02, 2.75e+02, 3.00e+02, 3.50e+02,
#        4.00e+02, 4.50e+02, 5.00e+02, 6.00e+02, 7.00e+02, 8.00e+02, 9.00e+02,
#        1.00e+03, 1.10e+03, 1.20e+03, 1.30e+03, 1.40e+03, 1.50e+03, 1.75e+03,
#        2.00e+03, 2.25e+03, 2.50e+03, 3.00e+03, 3.50e+03, 4.00e+03, 4.50e+03,
#        5.00e+03, 5.50e+03, 6.00e+03, 6.50e+03])
# Attributes:
#     units:      meters
#     long_name:  Depth at interface
#     axis:       Z
#     positive:   down, 'time': <xarray.IndexVariable 'time' (time: 334)> Size: 3kB
# array(['1993-01-01T12:00:00.000000000', '1993-01-02T12:00:00.000000000',
#        '1993-01-03T12:00:00.000000000', ..., '1993-11-28T12:00:00.000000000',
#        '1993-11-29T12:00:00.000000000', '1993-11-30T12:00:00.000000000'],
#       dtype='datetime64[ns]')
# Attributes:
#     long_name:      time
#     axis:           T
#     calendar_type:  GREGORIAN
#     bounds:         time_bnds, 'nv': <xarray.IndexVariable 'nv' (nv: 2)> Size: 16B
# array([1., 2.])
# Attributes:
#     long_name:  vertex number})

# %%
# terms = {}
# terms['heat'] = ['Th_tendency','T_advection_xy','T_tendency_vert_remap','boundary_forcing_heat_tendency','diabatic_heat_tendency','frazil_heat_tendency']

# # cell-by-cell budget xh=50,yh=300,zl=20
# fluxes = ds.T_advection_xy.isel(xh=50,yh=300,z_l=20).squeeze() + ds.T_tendency_vert_remap.isel(xh=50,yh=300,z_l=20).squeeze() + ds.boundary_forcing_heat_tendency.isel(xh=50,yh=300,z_l=20).squeeze() + ds.diabatic_heat_tendency.isel(xh=50,yh=300,z_l=20).squeeze() + ds.frazil_heat_tendency.isel(xh=50,yh=300,z_l=20).squeeze() 

# fig, ax = plt.subplots(1, 1, figsize=(6,6), dpi=250)
fluxes.isel(time=slice(1,-1)).plot(x='time')
# fluxes.plot(x='time')
# ds.Th_tendency.isel(xh=50,yh=300,z_l=20,time=slice(1,-1)).plot(x='time')
# diff = ds.Th_tendency.isel(xh=50,yh=300,z_l=20,time=slice(1,-1)) - fluxes.isel(time=slice(1,-1))
# diff.plot(x='time')
# ax.set_ylabel('W m$^{-2}$')
# ax.set_title('heat budget')
# ax.legend(['heat tendency','heat fluxes', 'difference'])

# fig, ax = plt.subplots(1, 1, figsize=(6,6), dpi=250)
# for term in terms['heat']:
#         ds[term].isel(xh=50,yh=300,z_l=20,time=slice(1,-1)).plot(x='time')
# diff.plot(x='time')
# ax.set_ylabel('W m$^{-2}$')
# ax.set_title('heat budget terms')
# ax.legend(terms['heat']+['residual'],fontsize=10)

# %%
# %%timeit 
# nanmasked = plt.get_cmap('cmo.tempo').copy()
# nanmasked.set_bad('black')
# plt.rcParams.update({'font.size': 8})
# day = 180
# fig, ax = plt.subplots(1, 1,figsize=(6,3),dpi=175)
# test = ds.o2min.isel(z_l=0).mean('time')*1e6
test.plot(x='xh',y='yh',cmap = nanmasked,cbar_kwargs={'label':'o2 [$\mu$mol/kg]'})
# plt.tight_layout()
# plt.gca().set_aspect('equal')
# ax.set_title('mean daily min o2')
# # ax.set_title(label='Date: ' + ds.time[day].dt.strftime('%Y-%m-%d').values)# + '  Depth: ' + str(dspo2.z_l[0].values) + ' m')
# ax.set_xlabel('longitude')
# ax.set_ylabel('latitude')

# # list(ds.keys())
# plt.rcParams.update({'font.size': 12})
# ds.o2min.isel(time=slice(100,270),xh=600,yh=40,z_l=20).plot(x='time',color='lightsteelblue')
# ds.o2max.isel(time=slice(100,270),xh=600,yh=40,z_l=20).plot(x='time',color='lightcoral')
# ds.o2.isel(time=slice(100,270),xh=600,yh=40,z_l=20).plot(x='time',color='black')
# Out:
# <unknown>:7: SyntaxWarning: invalid escape sequence '\m'
# 29.6 s ± 1.87 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
